# %% [markdown]
# # Download and  visualise AHN

# %% [markdown]
# With datafusion tools it is possible to automatically download AHN2 and AHN3 at any given location.
#
# First it is necessary to import the datafusion tools packages:

# %%
import numpy as np
import matplotlib.pylab as plt

from datafusiontools._core.data_input import Geometry
from DataFusionTools.spatial_utils import SpatialUtils, TypesAhn

# %% [markdown]
# ## AHN along lines

# %% [markdown]
# Define an array of points where you want to obtain AHN:

# %%
x_ini = 86433.84
y_ini = 439982.755

x, y = [], []
for i in range(2):
    x.append(x_ini + i)
    y.append(y_ini + i)

# %% [markdown]
# Collect the AHN3:

# %%
# initialize spatial utils
spatial_utils = SpatialUtils(ahn_type=TypesAhn.AHN3)
# get surface line
spatial_utils.get_ahn_surface_line(np.array([x, y]).T)

# %%
spatial_utils.AHN_data
# Out:
# array([[8.64338400e+04, 4.39982755e+05, 7.82299995e+00],
#        [8.64348400e+04, 4.39983755e+05, 6.11000001e-01]])

# %% [markdown]
# Visualise the results

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot()

ax.plot(np.sqrt(np.array(spatial_utils.AHN_data)[:, 0]**2 + np.array(spatial_utils.AHN_data)[:, 1]**2),
        np.array(spatial_utils.AHN_data)[:, 2], marker="x")
ax.set_xlabel("Distance [m]")
ax.set_ylabel("AHN [m]")
# Out:
# Text(0, 0.5, 'AHN [m]')

# %% [markdown]
# Extract AHN2:

# %%
# initialize spatial utils
spatial_utils2 = SpatialUtils(ahn_type=TypesAhn.AHN2)
# get surface line
spatial_utils2.get_ahn_surface_line(np.array([x, y]).T)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25788/2277435041.py in <module>
#       2 spatial_utils2 = SpatialUtils(ahn_type=TypesAhn.AHN2)
#       3 # get surface line
# ----> 4 spatial_utils2.get_ahn_surface_line(np.array([x, y]).T)
#
# c:\users\zuada\software_dev\datafusiontools\DataFusionTools\spatial_utils.py in get_ahn_surface_line(self, slice_line)
#      94         for result in results:
#      95             if result.exception() is not None:
# ---> 96                 raise result.exception()
#      97
#      98         # sort AHN points order
#
# ~\Miniconda3\envs\datafusiontools\lib\concurrent\futures\thread.py in run(self)
#      50
#      51         try:
# ---> 52             result = self.fn(*self.args, **self.kwargs)
#      53         except BaseException as exc:
#      54             self.future.set_exception(exc)
#
# c:\users\zuada\software_dev\datafusiontools\DataFusionTools\spatial_utils.py in collect_AHN_data(self, point, idx)
#     108         self.bbox = f"{point[0] - 1000}, {point[1] - 1000}, {point[0] + 1000}, {point[1] + 1000}"
#     109         response = requests.get(self.url_ahn, params=self.dictionary_parameters)
# --> 110         ahn_value = self.get_ahn_value_from_response(response)
#     111         self.surface_line.append([idx, point[0], point[1], ahn_value])
#
# c:\users\zuada\software_dev\datafusiontools\DataFusionTools\spatial_utils.py in get_ahn_value_from_response(response)
#      70             raise ValueError("The returned dictionary was not in the correct format.")
#      71         else:
# ---> 72             raise ConnectionError("Connection with the http://geodata.nationaalgeoregister.nl was not successful. ")
#      73
#      74     def get_ahn_surface_line(self, slice_line: Union[List, np.ndarray]):
#
# ConnectionError: Connection with the http://geodata.nationaalgeoregister.nl was not successful.

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot()

ax.plot(np.sqrt(np.array(spatial_utils.AHN_data)[:, 0]**2 + np.array(spatial_utils.AHN_data)[:, 1]**2),
        np.array(spatial_utils.AHN_data)[:, 2], marker="x", label="AHN3")

ax.plot(np.sqrt(np.array(spatial_utils2.AHN_data)[:, 0]**2 + np.array(spatial_utils2.AHN_data)[:, 1]**2),
        np.array(spatial_utils2.AHN_data)[:, 2], marker="o", label="AHN2")
ax.set_xlabel("Distance [m]")
ax.set_ylabel("AHN [m]")
ax.legend()

# %% [markdown]
# ## AHN along surfaces

# %% [markdown]
# Define a grid to collect the AHN data:

# %%
x_ini = 64664
y_ini = 393995

x, y = [], []
for i in range(10):
    x.append(x_ini + i * 10)
    y.append(y_ini + i * 10)
    
x, y = np.meshgrid(x, y, indexing="ij")

# %%
# initialize spatial utils
spacial_utils = SpatialUtils()
# get surface line
spacial_utils.get_ahn_surface_line(np.array([x.ravel(), y.ravel()]).T)

# %%
import matplotlib.tri as mtri
triang = mtri.Triangulation(np.array(spacial_utils.AHN_data)[:, 0], np.array(spacial_utils.AHN_data)[:, 1])
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(projection='3d')
ax.plot_trisurf(triang, np.array(spacial_utils.AHN_data)[:, 2], cmap='jet')
ax.set_xlabel("X coordinate [m]")
ax.set_ylabel("Y coordinate [m]")
ax.set_zlabel("AHN [m]")
plt.show()
